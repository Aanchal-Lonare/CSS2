# %% [markdown]
# 1. Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
# navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
# items must change their text color on hover.
#
# ->
#
#  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         *{
#     margin: 0;
#     padding: 0;
#     box-sizing: border-box;
#     color: #ffffff;
# }
#
# body{
#     font-family: Arial, Helvetica, sans-serif;
# }
#
# .navbar{
#     background-color: rgb(73, 73, 224);
#     padding: 15px 20px;
# }
#
# .nav-links {
#     list-style: none;
#     display: flex;
#     justify-content:flex-start;
#     gap: 40px;
# }
#
# .nav-links li{
#     padding: 10px 20px;
# }
#
# .nav-links a{
#     text-decoration:underline;
#     color: white;
#     font-size: 17px ;
#     transition: color 0.3s ease;
# }
#
# .nav-links a:hover{
#     color: red;
# }
#     </style>
# </head>
# <body>
#     <nav class="navbar">
#         <ul class="nav-links">
#             <li><a href="@">Home</a></li>
#             <li><a href="@"> About Us</a></li>
#             <li><a href="@">Contact</a></li>
#             <li><a href="@">Blog</a></li>
#             <li><a href="@">Login</a></li>
#         </ul>
#     </nav>
# </body>
# </html>
#
# 2.  Create a div centered with an image and paragraph similar to the image mentioned below.
#
# ->
#
#     <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#
#     <style>
#         body{
#     font-family: Arial, Helvetica, sans-serif;
#     background-color: white;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     height: 90vh;
# }
#
# .card{
#     height: 400px;
#     width: 350px;
#     border-radius: 12px;
#     box-shadow: 0 4px 10px rgba(0, 0, 0, 0.7);
#     background-color: rgb(230, 222, 71);
#     text-align: center;
#
# }
#
# .card img{
#     height: 300px;
#     width: 315px;
#     object-fit: cover;
#     padding-top: 20px;
#     border-radius: 10px;
# }
#     </style>
# </head>
# <body>
#     <div class="card">
#        <img src=" https://tse2.mm.bing.net/th?id=OIP.fkIdJRDwTgvsdV7Lu3EjOAHaHa&pid=Api&P=0&h=180">
#        <div class="card-content">
#         <p>Cource Name:PW Skills fullstack web development</p>
#        </div>
#
#     </div>
# </body>
# </html>
#
# 3. Create a navigation bar similar to question 1. For each navigation item, use a different border style ??
#
# ->
#
#    <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             margin: 0;
#             font-family: 'Gill Sans', 'Gill Sans MT', Calibri, 'Trebuchet MS', sans-serif;
#         }
#
#         nav{
#             background-color: rgb(81, 81, 225);
#             display: flex;
#             padding: 20px 15px;
#         }
#
#         nav a{
#             color: white;
#             text-decoration: none;
#             font-size:20px;
#            box-sizing: border-box;
#            margin-right:20px ;
#            padding: 5px 15px ;
#            display: inline-block;
#         }
#
#         nav a:hover{
#             color: rgb(244, 244, 86);
#
#
#         }
#
#         nav a:nth-child(1){
#             border: 2px solid white;
#         }
#         nav a:nth-child(2){
#             border: 2px dotted white;
#         }
#         nav a:nth-child(3){
#             border: 2px dashed white;
#         }
#         nav a:nth-child(4){
#             border: 2px double white;
#         }
#         nav a:nth-child(5){
#             border: 2px groove white;
#         }
#     </style>
# </head>
# <body>
#     <nav>
#         <a href="@">Home</a>
#         <a href="@">About us</a>
#         <a href="@">Contact</a>
#         <a href="@">Blog</a>
#         <a href="@">Login</a>
#     </nav>
# </body>
# </html>
#
#  4. Create a simple webpage with an image and make the image circular using border-radius ??
#
#  ->
#
#  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Circular Image Example</title>
#     <style>
#         body{
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 25px;
#             text-align: center;
#             margin-top: 50px;
#
#         }
#
#         .circle-img{
#             height: 300px;
#             width: 300px;
#             border-radius: 50%;
#             border: 2px solid black;
#             object-fit: cover;
#         }
#     </style>
# </head>
# <body>
#     <h2>My Circular Image</h2>
#     <img src=" https://plus.unsplash.com/premium_photo-1675448891094-0f3acc556fdb?w=500&auto=format&fit=crop&q=60&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHx0b3BpYy1mZWVkfDV8NnNNVmpUTFNrZVF8fGVufDB8fHx8fA%3D%3D" class="circle-img">
# </body>
# </html>
#
# 5.  Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
# align center to the page, below the heading have an image of Google fonts and a paragraph about Google
# fonts in font “Montserrat” paragraph font style should be“montserrat” font ??
#
# ->
#
#  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Google Font Blog</title>
#     <link href="https://fonts.googleapis.com/css2?family=Montserrat&family=Oswald&display=swap" rel="stylesheet">
#
#     <style>
#         body{
#             font-family: 'Montserrat', sans-serif;
#             margin: 0;
#             padding: 10px;
#            background-color: white;
#             text-align: center;
#         }
#
#         h1{
#             font-family: 'Oswald' sans-serif ;
#             font-size: 36px;
#             margin-bottom: 15px;
#         }
#
#         img{
#             width:250px ;
#             height:auto ;
#             margin-bottom: 20px;
#             max-width: 90%;
#         }
#
#         p{
#            font-size: 18px;
#            max-width: 600px;
#            margin: 0 auto;
#            line-height: 1.6;
#         }
#
#
#     </style>
# </head>
# <body>
#     <h1>Google font</h1>
#     <img src=" https://tse3.mm.bing.net/th?id=OIP.6N8ZySXEpA-1S_38mIPv7QHaFv&pid=Api&P=0&h=180" alt="font img">
#
#     <p> Google Fonts (formerly known as Google Web Fonts) is a computer font and web font service owned by Google. This includes free and open source font families, an interactive web directory for browsing the library, and APIs for using the fonts via CSS[2] and Android.[3] Google Fonts is also used with Google Workspace software such as Docs, Sheets, Drawings and Slides.
#
#         <!-- Google Fonts was launched in 2010 and revamped in 2011,2016,2020 and 2023 On March 3, 2020, Google updated the catalog website with support for variable fonts.[citation needed] On March 2, 2021, the Google Fonts team announced they were adding support for open source icons. -->
#     </p>
# </body>
# </html>
#
# 6. Create a simple website as mentioned in the below image. You can get the assets by visiting https://
# pwskills.com/about-us ??
#
# ->
#
#  <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initil-scale=1.0">
#     <title>Document</title>
#     <style>
#
#         body{
#            height: 90vh;
#             width: 80vw;
#             margin: 30px ;
#             color: black;
#             font-family: Arial, Helvetica, sans-serif;
#              border: 2px solid black;
#
#         }
#         h2{
#             font-size: 35px;
#             text-align: center;
#             margin-bottom: 10px;
#         }
#
#         p{
#             margin: 40px 40px;
#            font-size: 19px;
#             text-align:justify;
#             margin-bottom: 20px;
#             color: gray;
#         }
#
#         img{
#             height: 65%;
#             width: 94%;
#             display: block;
#             margin: 30px 35px;
#
#         }
#
#
#     </style>
# </head>
# <body>
#
#         <h2>About us</h2>
#
#         <p>PW Skill's mission is to permeate through every student/professional's outlook
#             towards jobs and change their attitude and perspective from "How can i do it??" to "Of Course i can Do it".
#             We aim to do this by providing exceptional up skilling courses at affortable rates, while being tech-forward
#             so anyone, anywhere can access and improve their ability to be successful in life.
#         </p>
#
#         <img src=" https://pwskills.com/images/aboutUs/aboutUs.png" >
#
#
# </body>
# </html>
#
# 7. Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as
# default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output??
#
# ->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Hover Card Example</title>
#     <style>
#         body{
#             margin: 0;
#             padding: 0;
#             height: 100vh;
#             background-color: white;
#             font-family: Arial, Helvetica, sans-serif;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             /* box-sizing: border-box; */
#
#         }
#
#         .card{
#              width: 400px;
#              height: 310px;
#              padding:5px ;
#              box-shadow: 1px 4px 8px rgba(0, 0, 0, 0.2);
#              border-radius: 12px;
#              text-align: center;
#              opacity: 0.3;
#              transition: opacity 0.4s ease;
#         }
#
#         .card:hover{
#             opacity: 1;
#         }
#          .card h2{
#             font-size:24px ;
#             margin-bottom: 10px ;
#         }
#         p{
#             font-size: 14px;
#             text-align:left;
#             margin-left: 23px;
#
#         }
#     </style>
# </head>
# <body>
#     <div class="card">
#         <h2>Hover Card</h2>
#         <img src=" https://tse4.mm.bing.net/th?id=OIP.hb_dQ_654_jfjDJlzJxcIwHaDt&pid=Api&P=0&h=180">
#
#         <p><b>Course Name:</b> PW SKills web development </p>
#     </div>
# </body>
# </html>
#
# 8. Create a simple list of items as mentioned in the below image ??
#
# ->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>List of items</title>
#     <style>
#         body{
#             height: 200px;
#             width: 40vw;
#             box-sizing: border-box;
#             border: 2px solid black;
#             margin: 20px ;
#             padding: 5px 10px;
#             font-size: 18px ;
#         }
#     </style>
# </head>
# <body>
#     <h1>Requirements</h1>
#     <ol type="i">
#         <li>System with minimum i3 processor or better.</li>
#         <li>At least 4 GB of RAM.</li>
#         <li>Working internet connection.</li>
#         <li>Dadication to learn</li>
#     </ol>
# </body>
# </html>
